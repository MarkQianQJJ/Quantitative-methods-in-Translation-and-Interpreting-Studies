# %%
from stanfordcorenlp import StanfordCoreNLP

# %%
nlp = StanfordCoreNLP(r'D:\vscode\stanford-corenlp-4.5.8')

# %%
sentence = "A colony of red wolves that was reintroduced in North Carolina in 1987 is failing because of poor management and fierce state opposition from game officials and hunters who are killing it, said the five-year review, prepared by the U.S. Fish and Wildlife Service's Southeastern Regional Office and released Tuesday, April 24."

# %%
# Tokenization
tokens = nlp.word_tokenize(sentence)
print("Tokens:", tokens)
# Out:
# Tokens: ['A', 'colony', 'of', 'red', 'wolves', 'that', 'was', 'reintroduced', 'in', 'North', 'Carolina', 'in', '1987', 'is', 'failing', 'because', 'of', 'poor', 'management', 'and', 'fierce', 'state', 'opposition', 'from', 'game', 'officials', 'and', 'hunters', 'who', 'are', 'killing', 'it', ',', 'said', 'the', 'five', '-', 'year', 'review', ',', 'prepared', 'by', 'the', 'U.S.', 'Fish', 'and', 'Wildlife', 'Service', "'s", 'Southeastern', 'Regional', 'Office', 'and', 'released', 'Tuesday', ',', 'April', '24', '.']

# %%
# Part-of-Speech (POS) Tagging
pos_tags = nlp.pos_tag(sentence)
print("POS Tags:", pos_tags)
# Out:
# POS Tags: [('A', 'DT'), ('colony', 'NN'), ('of', 'IN'), ('red', 'JJ'), ('wolves', 'NNS'), ('that', 'WDT'), ('was', 'VBD'), ('reintroduced', 'VBN'), ('in', 'IN'), ('North', 'NNP'), ('Carolina', 'NNP'), ('in', 'IN'), ('1987', 'CD'), ('is', 'VBZ'), ('failing', 'VBG'), ('because', 'IN'), ('of', 'IN'), ('poor', 'JJ'), ('management', 'NN'), ('and', 'CC'), ('fierce', 'JJ'), ('state', 'NN'), ('opposition', 'NN'), ('from', 'IN'), ('game', 'NN'), ('officials', 'NNS'), ('and', 'CC'), ('hunters', 'NNS'), ('who', 'WP'), ('are', 'VBP'), ('killing', 'VBG'), ('it', 'PRP'), (',', ','), ('said', 'VBD'), ('the', 'DT'), ('five', 'CD'), ('-', 'HYPH'), ('year', 'NN'), ('review', 'NN'), (',', ','), ('prepared', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('U.S.', 'NNP'), ('Fish', 'NNP'), ('and', 'CC'), ('Wildlife', 'NNP'), ('Service', 'NNP'), ("'s", 'POS'), ('Southeastern', 'NNP'), ('Regional', 'NNP'), ('Office', 'NNP'), ('and', 'CC'), ('released', 'VBN'), ('Tuesday', 'NNP'), (',', ','), ('April', 'NNP'), ('24', 'CD'), ('.', '.')]

# %%
# Named Entity Recognition (NER)
ner_tags = nlp.ner(sentence)
print("NER Tags:", ner_tags)
# Out:
# NER Tags: [('A', 'O'), ('colony', 'O'), ('of', 'O'), ('red', 'O'), ('wolves', 'O'), ('that', 'O'), ('was', 'O'), ('reintroduced', 'O'), ('in', 'O'), ('North', 'STATE_OR_PROVINCE'), ('Carolina', 'STATE_OR_PROVINCE'), ('in', 'O'), ('1987', 'DATE'), ('is', 'O'), ('failing', 'O'), ('because', 'O'), ('of', 'O'), ('poor', 'O'), ('management', 'O'), ('and', 'O'), ('fierce', 'O'), ('state', 'O'), ('opposition', 'O'), ('from', 'O'), ('game', 'O'), ('officials', 'O'), ('and', 'O'), ('hunters', 'O'), ('who', 'O'), ('are', 'O'), ('killing', 'O'), ('it', 'O'), (',', 'O'), ('said', 'O'), ('the', 'O'), ('five', 'DURATION'), ('-', 'DURATION'), ('year', 'DURATION'), ('review', 'O'), (',', 'O'), ('prepared', 'O'), ('by', 'O'), ('the', 'O'), ('U.S.', 'COUNTRY'), ('Fish', 'O'), ('and', 'O'), ('Wildlife', 'ORGANIZATION'), ('Service', 'ORGANIZATION'), ("'s", 'O'), ('Southeastern', 'ORGANIZATION'), ('Regional', 'ORGANIZATION'), ('Office', 'ORGANIZATION'), ('and', 'O'), ('released', 'O'), ('Tuesday', 'DATE'), (',', 'DATE'), ('April', 'DATE'), ('24', 'DATE'), ('.', 'O')]

# %%
# Constituency Parsing
constituency = nlp.parse(sentence)
print("constituency:", constituency)
# Out:
# constituency: (ROOT
#   (S
#     (NP
#       (NP (DT A) (NN colony))
#       (PP (IN of)
#         (NP
#           (NP (JJ red) (NNS wolves))
#           (SBAR
#             (WHNP (WDT that))
#             (S
#               (VP (VBD was)
#                 (VP (VBN reintroduced)
#                   (PP (IN in)
#                     (NP
#                       (NP (NNP North) (NNP Carolina))
#                       (PP (IN in)
#                         (NP (CD 1987))))))))))))
#     (VP (VBZ is)
#       (VP (VBG failing)
#         (SBAR (IN because)
#           (S
#             (NP
#               (NP
#                 (PP (IN of)
#                   (NP
#                     (NP (JJ poor) (NN management))
#                     (CC and)
#                     (NP (JJ fierce) (NN state) (NN opposition)))))
#               (PP (IN from)
#                 (NP
#                   (NP (NN game) (NNS officials)
#                     (CC and)
#                     (NNS hunters))
#                   (SBAR
#                     (WHNP (WP who))
#                     (S
#                       (VP (VBP are)
#                         (VP (VBG killing)
#                           (NP (PRP it)))))))))
#             (, ,)
#             (VP (VBD said)
#               (NP
#                 (NP (DT the)
#                   (NML (CD five) (HYPH -) (NN year))
#                   (NN review))
#                 (, ,)
#                 (VP
#                   (VP (VBN prepared)
#                     (PP (IN by)
#                       (NP
#                         (NP (DT the) (NNP U.S.)
#                           (NML (NNP Fish)
#                             (CC and)
#                             (NNP Wildlife))
#                           (NNP Service) (POS 's))
#                         (NNP Southeastern) (NNP Regional) (NNP Office))))
#                   (CC and)
#                   (VP (VBN released)
#                     (NP-TMP (NNP Tuesday)))))
#               (, ,)
#               (NP-TMP (NNP April) (CD 24)))))))
#     (. .)))

# %%
# Dependency Parsing
dependencies = nlp.dependency_parse(sentence)
print("Dependencies:", dependencies)
# Out:
# Dependencies: [('ROOT', 0, 15), ('det', 2, 1), ('nsubj', 15, 2), ('case', 5, 3), ('amod', 5, 4), ('nmod', 2, 5), ('nsubj:pass', 8, 6), ('aux:pass', 8, 7), ('acl:relcl', 2, 8), ('case', 11, 9), ('compound', 11, 10), ('obl', 8, 11), ('case', 13, 12), ('obl', 8, 13), ('aux', 15, 14), ('case', 19, 16), ('fixed', 16, 17), ('amod', 19, 18), ('obl', 15, 19), ('cc', 23, 20), ('amod', 23, 21), ('compound', 23, 22), ('conj', 19, 23), ('case', 26, 24), ('compound', 26, 25), ('nmod', 23, 26), ('cc', 28, 27), ('conj', 26, 28), ('nsubj', 31, 29), ('aux', 31, 30), ('acl:relcl', 26, 31), ('obj', 31, 32), ('punct', 15, 33), ('conj', 15, 34), ('det', 39, 35), ('nummod', 38, 36), ('punct', 38, 37), ('compound', 39, 38), ('obj', 34, 39), ('punct', 15, 40), ('conj', 15, 41), ('case', 52, 42), ('det', 48, 43), ('compound', 48, 44), ('compound', 48, 45), ('cc', 47, 46), ('conj', 45, 47), ('nmod:poss', 52, 48), ('case', 48, 49), ('compound', 52, 50), ('compound', 52, 51), ('obl', 41, 52), ('cc', 54, 53), ('conj', 15, 54), ('obl:tmod', 54, 55), ('punct', 15, 56), ('obl:tmod', 15, 57), ('nummod', 57, 58), ('punct', 15, 59)]

# %%
# Close the connection
nlp.close()
